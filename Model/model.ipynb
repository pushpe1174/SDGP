# %% [markdown]
# # Currency detection yolov8 model

# %% [markdown]
# ### Data preprocessing

# %%
import os
import cv2

path = ""
savepath = ""
files = os.listdir(path)

for filname in files:
	img = cv2.imread(os.path.join(path, filname), cv2.IMREAD_UNCHANGED)
	dim = (640, 640)
	resized = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)	
	cv2.imwrite(os.path.join(savepath, filname), resized)
	print("Processed file: ", filname)

# %% [markdown]
# ### Loading Data

# %%
# !pip install -U --no-cache-dir gdown --pre
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !gdown 1RXvsrOKBzZmcLY54WSlAQ3cKvRm8AD7V
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1RXvsrOKBzZmcLY54WSlAQ3cKvRm8AD7V
# To: /content/CompleteData 2.zip
# 100% 456M/456M [00:03<00:00, 139MB/s]

# %%
# !unzip /content/CompleteData.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: CompleteData 2/train/images/5000_259.jpg
#   inflating: CompleteData 2/train/images/5000_1.jpg
#   inflating: CompleteData 2/train/images/144.jpg
#   inflating: CompleteData 2/train/images/100_399.jpg
#   inflating: CompleteData 2/train/images/150.jpg
#   inflating: CompleteData 2/train/images/20_365.jpg
#   inflating: CompleteData 2/train/images/636.jpg
#   inflating: CompleteData 2/train/images/100_41.jpg
#   inflating: CompleteData 2/train/images/1000_11.jpg
#   inflating: CompleteData 2/train/images/100_400.jpg
#   inflating: CompleteData 2/train/images/45.jpg
#   inflating: CompleteData 2/train/images/1000_218.jpg
#   inflating: CompleteData 2/train/images/100_366.jpg
#   inflating: CompleteData 2/train/images/100_372.jpg
#   inflating: CompleteData 2/train/images/3.jpg
#   inflating: CompleteData 2/train/images/100_55.jpg
#   inflating: CompleteData 2/train/images/51.jpg
# ...

# %% [markdown]
# ## Install Libraries

# %%
# !pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 496.9/496.9 KB 29.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 189.1/189.1 KB 20.8 MB/s eta 0:00:00
# ...

# %%
# !pip install clearml
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 972.3/972.3 KB 48.4 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## Setup ClearMl

# %%
# !clearml-init
# Out:
# ClearML SDK setup process
#
# Please create new clearml credentials through the settings page in your `clearml-server` web app (e.g. http://localhost:8080//settings/workspace-configuration)
# Or create a free account at https://app.clear.ml/settings/workspace-configuration
#
# In settings page, press "Create new credentials", then press "Copy to clipboard".
#
# Paste copied configuration here:
# api {      # Ganindu Prabasha Pushpakumara's workspace     web_server: https://app.clear.ml     api_server: https://api.clear.ml     files_server: https://files.clear.ml     credentials {         "access_key" = "1MLJ6O1FMUIHXPH5VOUG"         "secret_key"  = "BPugGcNKIxILRUdmdwSPgpeuVF6mTfrgnea3CXFCAgOFZS5FVk"     } }
# Detected credentials key="1MLJ6O1FMUIHXPH5VOUG" secret="BPug***"
#
# ClearML Hosts configuration:
# Web App: https://app.clear.ml
# API: https://api.clear.ml
# File Store: https://files.clear.ml
#
# Verifying credentials ...
# Credentials verified!
#
# ...

# %% [markdown]
# ## Train Process

# %% [markdown]
# Loading the pretrained weight model

# %%
from ultralytics import YOLO
model = YOLO("yolov8m.pt")  # load a pre weight

# %%
model.train(data = '/content/data.yaml' , epochs =10)
# Out:
# Ultralytics YOLOv8.0.54 🚀 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
results = model('/content/42.jpeg')
# Out:
# image 1/1 /content/42.jpeg: 416x640 1 500, 2 1000s, 44.3ms
# Speed: 0.6ms preprocess, 44.3ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
